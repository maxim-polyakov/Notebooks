# %%
import wave
import sys

from vosk import Model, KaldiRecognizer, SetLogLevel

# %%
# You can set log level to -1 to disable debug messages
#SetLogLevel(0)

wf = wave.open("audio_2024-06-07_15-58-48.wav", "rb")
#if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getcomptype() != "NONE":
    #print("Audio file must be WAV format mono PCM.")
    #sys.exit(1)

# %%
wf

# %%
# You can also init model by name or with a folder path
model = Model(model_name="vosk-model-ru-0.42")
# model = Model("models/en")

rec = KaldiRecognizer(model, wf.getframerate())
rec.SetWords(True)
rec.SetPartialWords(True)

# %%
while True:
    data = wf.readframes(4000)
    if len(data) == 0:
        break
    if rec.AcceptWaveform(data):
        print(rec.Result())
    else:
        print(rec.PartialResult())
# Out:
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это",
#   "partial_result" : [{
#       "conf" : 0.958675,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.967326,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743241,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999127,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999127,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999960,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999960,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.778044,
#       "end" : 4.349826,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743023,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999973,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999973,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.738820,
#       "end" : 4.349549,
#       "start" : 3.090000,
#       "word" : "последние"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние может быть даже и",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
#       "conf" : 0.990850,
#       "end" : 1.320000,
#       "start" : 0.840000,
#       "word" : "это"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.680000,
#       "start" : 1.320000,
#       "word" : "один"
#     }, {
#       "conf" : 1.000000,
#       "end" : 1.800000,
#       "start" : 1.680000,
#       "word" : "из"
#     }, {
#       "conf" : 1.000000,
#       "end" : 2.130000,
#       "start" : 1.800000,
#       "word" : "лучших"
#     }, {
#       "conf" : 0.743026,
#       "end" : 2.610000,
#       "start" : 2.130000,
#       "word" : "боев"
#     }, {
#       "conf" : 0.999959,
#       "end" : 2.940000,
#       "start" : 2.610001,
#       "word" : "вообще"
#     }, {
#       "conf" : 0.999959,
#       "end" : 3.090000,
#       "start" : 2.940000,
#       "word" : "за"
#     }, {
#       "conf" : 0.643104,
#       "end" : 4.349469,
#       "start" : 3.090000,
#       "word" : "последние"
#     }, {
#       "conf" : 1.000000,
#       "end" : 5.460000,
#       "start" : 5.100345,
#       "word" : "может"
#     }, {
#       "conf" : 0.976387,
#       "end" : 5.609501,
#       "start" : 5.460000,
#       "word" : "быть"
#     }, {
#       "conf" : 1.000000,
#       "end" : 5.881171,
#       "start" : 5.609501,
#       "word" : "даже"
#     }, {
#       "conf" : 0.863639,
#       "end" : 5.940000,
#       "start" : 5.881171,
#       "word" : "и"
#     }]
# }
# {
#   "partial" : "макс это один из лучших боев вообще за последние может быть даже и",
#   "partial_result" : [{
#       "conf" : 0.981989,
#       "end" : 0.840000,
#       "start" : 0.450000,
#       "word" : "макс"
#     }, {
# ...
#     }, {
#       "conf" : 0.996097,
#       "end" : 15.180000,
#       "start" : 14.547060,
#       "word" : "ударника"
#     }, {
#       "conf" : 1.000000,
#       "end" : 15.749907,
#       "start" : 15.241832,
#       "word" : "и"
#     }, {
#       "conf" : 0.529550,
#       "end" : 16.199819,
#       "start" : 15.780000,
#       "word" : "хорошего"
#     }, {
#       "conf" : 1.000000,
#       "end" : 16.770000,
#       "start" : 16.199819,
#       "word" : "ударника"
#     }, {
#       "conf" : 0.706489,
#       "end" : 17.182910,
#       "start" : 16.890000,
#       "word" : "ну"
#     }, {
#       "conf" : 0.338022,
#       "end" : 17.576700,
#       "start" : 17.220000,
#       "word" : "реально"
#     }, {
#       "conf" : 0.769226,
#       "end" : 18.090000,
#       "start" : 17.576700,
#       "word" : "выслушать"
#     }, {
#       "conf" : 0.757965,
#       "end" : 18.238742,
#       "start" : 18.119850,
#       "word" : "да"
#     }, {
#       "conf" : 0.654966,
#       "end" : 18.540000,
#       "start" : 18.238742,
#       "word" : "рынков"
#     }]
# }
# {
#   "partial" : "ислама хорошо то есть как борца на хорошую ударника и хорошего ударника ну реально выслушать да рынков",
#   "partial_result" : [{
#       "conf" : 0.392759,
#       "end" : 12.356939,
#       "start" : 11.880000,
#       "word" : "ислама"
#     }, {
#       "conf" : 0.867757,
#       "end" : 12.750000,
#       "start" : 12.360038,
#       "word" : "хорошо"
#     }, {
#       "conf" : 0.989751,
#       "end" : 12.900000,
#       "start" : 12.750000,
#       "word" : "то"
#     }, {
#       "conf" : 0.986197,
#       "end" : 13.019816,
#       "start" : 12.900000,
#       "word" : "есть"
#     }, {
#       "conf" : 1.000000,
#       "end" : 13.170000,
#       "start" : 13.019816,
#       "word" : "как"
#     }, {
#       "conf" : 0.996244,
#       "end" : 13.860000,
#       "start" : 13.170000,
#       "word" : "борца"
#     }, {
#       "conf" : 0.378448,
#       "end" : 14.070000,
#       "start" : 13.890000,
#       "word" : "на"
#     }, {
#       "conf" : 0.376775,
#       "end" : 14.547060,
#       "start" : 14.115160,
#       "word" : "хорошую"
#     }, {
#       "conf" : 0.996097,
#       "end" : 15.180000,
#       "start" : 14.547060,
#       "word" : "ударника"
#     }, {
#       "conf" : 1.000000,
#       "end" : 15.749907,
#       "start" : 15.241832,
#       "word" : "и"
#     }, {
#       "conf" : 0.529550,
#       "end" : 16.199819,
#       "start" : 15.780000,
#       "word" : "хорошего"
#     }, {
#       "conf" : 1.000000,
#       "end" : 16.770000,
#       "start" : 16.199819,
#       "word" : "ударника"
#     }, {
#       "conf" : 0.706489,
#       "end" : 17.182910,
#       "start" : 16.890000,
#       "word" : "ну"
#     }, {
#       "conf" : 0.338022,
#       "end" : 17.576700,
#       "start" : 17.220000,
#       "word" : "реально"
#     }, {
#       "conf" : 0.769226,
#       "end" : 18.090000,
#       "start" : 17.576700,
#       "word" : "выслушать"
#     }, {
#       "conf" : 0.757965,
#       "end" : 18.238742,
#       "start" : 18.119850,
#       "word" : "да"
#     }, {
#       "conf" : 0.654966,
#       "end" : 18.540000,
#       "start" : 18.238742,
#       "word" : "рынков"
#     }]
# }
# {
#   "result" : [{
#       "conf" : 0.903137,
#       "end" : 12.360000,
#       "start" : 11.880000,
#       "word" : "ислама"
#     }, {
#       "conf" : 1.000000,
#       "end" : 12.750000,
#       "start" : 12.360000,
#       "word" : "хорошо"
#     }, {
#       "conf" : 1.000000,
#       "end" : 12.900000,
#       "start" : 12.750000,
#       "word" : "то"
#     }, {
#       "conf" : 1.000000,
#       "end" : 13.020000,
#       "start" : 12.900000,
#       "word" : "есть"
#     }, {
#       "conf" : 1.000000,
#       "end" : 13.170000,
#       "start" : 13.020000,
#       "word" : "как"
#     }, {
#       "conf" : 1.000000,
#       "end" : 13.860000,
#       "start" : 13.170000,
#       "word" : "борца"
#     }, {
#       "conf" : 1.000000,
#       "end" : 14.070000,
#       "start" : 13.890000,
#       "word" : "но"
#     }, {
#       "conf" : 1.000000,
#       "end" : 14.130000,
#       "start" : 14.070000,
#       "word" : "и"
#     }, {
#       "conf" : 1.000000,
#       "end" : 14.550000,
#       "start" : 14.130000,
#       "word" : "хорошего"
#     }, {
#       "conf" : 1.000000,
#       "end" : 15.180000,
#       "start" : 14.550000,
#       "word" : "ударника"
#     }, {
#       "conf" : 1.000000,
#       "end" : 15.750000,
#       "start" : 15.240000,
#       "word" : "и"
#     }, {
#       "conf" : 1.000000,
#       "end" : 16.200000,
#       "start" : 15.780000,
#       "word" : "хорошего"
#     }, {
#       "conf" : 1.000000,
#       "end" : 16.770000,
#       "start" : 16.200000,
#       "word" : "ударника"
#     }, {
#       "conf" : 0.958159,
#       "end" : 17.189952,
#       "start" : 16.890000,
#       "word" : "ну"
#     }, {
#       "conf" : 0.948854,
#       "end" : 17.580000,
#       "start" : 17.220000,
#       "word" : "реально"
#     }, {
#       "conf" : 0.948854,
#       "end" : 18.090000,
#       "start" : 17.580000,
#       "word" : "выслушать"
#     }, {
#       "conf" : 0.948854,
#       "end" : 18.240000,
#       "start" : 18.120000,
#       "word" : "да"
#     }, {
#       "conf" : 0.948854,
#       "end" : 18.480000,
#       "start" : 18.240000,
#       "word" : "рынка"
#     }, {
#       "conf" : 0.948854,
#       "end" : 18.900000,
#       "start" : 18.480000,
#       "word" : "удастся"
#     }, {
#       "conf" : 0.948854,
#       "end" : 19.020000,
#       "start" : 18.900000,
#       "word" : "на"
#     }, {
#       "conf" : 0.948854,
#       "end" : 19.440000,
#       "start" : 19.020000,
#       "word" : "барьер"
#     }],
#   "text" : "ислама хорошо то есть как борца но и хорошего ударника и хорошего ударника ну реально выслушать да рынка удастся на барьер"
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что",
#   "partial_result" : [{
#       "conf" : 0.580941,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 0.953679,
#       "end" : 21.240000,
#       "start" : 21.132261,
#       "word" : "что"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.870000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 22.049855,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }
# {
#   "partial" : "напоминаю что в этом месяце",
#   "partial_result" : [{
#       "conf" : 0.579846,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270341,
#       "start" : 21.132195,
#       "word" : "что"
#     }, {
#       "conf" : 0.935710,
#       "end" : 21.300000,
#       "start" : 21.270341,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 22.049855,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }]
# }

# %%
print(rec.FinalResult())
# Out:
# {
#   "result" : [{
#       "conf" : 0.771113,
#       "end" : 21.120000,
#       "start" : 20.610000,
#       "word" : "напоминаю"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.270000,
#       "start" : 21.126866,
#       "word" : "что"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.300000,
#       "start" : 21.270000,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 21.510000,
#       "start" : 21.300000,
#       "word" : "этом"
#     }, {
#       "conf" : 1.000000,
#       "end" : 22.050000,
#       "start" : 21.510000,
#       "word" : "месяце"
#     }, {
#       "conf" : 1.000000,
#       "end" : 22.890000,
#       "start" : 22.080000,
#       "word" : "дерётся"
#     }, {
#       "conf" : 1.000000,
#       "end" : 23.190000,
#       "start" : 22.890000,
#       "word" : "опять"
#     }, {
#       "conf" : 1.000000,
#       "end" : 23.520000,
#       "start" : 23.190000,
#       "word" : "конор"
#     }, {
#       "conf" : 1.000000,
#       "end" : 23.970000,
#       "start" : 23.520000,
#       "word" : "макгрегор"
#     }, {
#       "conf" : 1.000000,
#       "end" : 24.030000,
#       "start" : 23.970000,
#       "word" : "в"
#     }, {
#       "conf" : 1.000000,
#       "end" : 24.390000,
#       "start" : 24.030000,
#       "word" : "конце"
#     }, {
#       "conf" : 1.000000,
#       "end" : 24.690000,
#       "start" : 24.390000,
#       "word" : "июня"
#     }, {
#       "conf" : 0.968535,
#       "end" : 25.140000,
#       "start" : 24.690000,
#       "word" : "выходит"
#     }],
#   "text" : "напоминаю что в этом месяце дерётся опять конор макгрегор в конце июня выходит"
# }
